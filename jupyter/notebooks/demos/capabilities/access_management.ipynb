# %% [markdown]
# # Access management

# %% [markdown]
# ## Access to management function with identity token

# %%
from libs.helpers.utils import get_featuremesh_config

fm_config = get_featuremesh_config()

__YOUR_IDENTITY_TOKEN__ = fm_config['identity_token']

# %%
import featuremesh
from featuremesh import AccessClient

featuremesh.set_default('access.host', fm_config['access.host'])

client_access = AccessClient(identity_token=__YOUR_IDENTITY_TOKEN__)
client_access.list_projects()
# Out:
# [{'project_id': '546796ff-15f1-4dc9-a035-59d1642771b5',
#   'project_reference': '74bea521-1d27-47fe-bfe9-d5b478c02d18/default',
#   'org_name': '74bea521-1d27-47fe-bfe9-d5b478c02d18',
#   'project_name': 'default',
#   'role': 'OWNER',
#   'granted_at': '2026-03-02T10:26:55.153035'}]

# %% [markdown]
# ## Access to a project with an identity token

# %%
from featuremesh import generate_access_token

__YOUR_ACCESS_TOKEN__ = generate_access_token(
    identity_token=__YOUR_IDENTITY_TOKEN__, 
    project='default'
)

# %%
from featuremesh import BatchClient, Backend
import duckdb

featuremesh.set_default('managed.host', fm_config['managed.host'])
client_duckdb = BatchClient(
    access_token=__YOUR_ACCESS_TOKEN__,
    backend=Backend.DUCKDB,
    sql_executor=lambda sql: duckdb.sql(sql).df()
)
client_duckdb.query('SELECT 1+2').dataframe
# Out:
#    UNNAMED_FEATURE_28FUVH
# 0                       3

# %% [markdown]
# ## Decode any token

# %%
from featuremesh import decode_token

print("Identity token:\n", decode_token(__YOUR_IDENTITY_TOKEN__))
print("\nAccess token:\n", decode_token(__YOUR_ACCESS_TOKEN__))
# Out:
# Identity token:
#  {'success': True, 'token_info': {'token_type': 'USER_TOKEN', 'user_id': '74bea521-1d27-47fe-bfe9-d5b478c02d18', 'email': 'npissard@gmail.com', 'issued_at': '2026-03-02T10:26:55+00:00', 'expires_at': '2027-03-02T10:26:55+00:00', 'is_expired': False, 'is_invalidated': False}}
#
# Access token:
#  {'success': True, 'token_info': {'token_type': 'USER_PROJECT_TOKEN', 'user_id': '74bea521-1d27-47fe-bfe9-d5b478c02d18', 'email': 'npissard@gmail.com', 'issued_at': '2026-04-01T13:42:48+00:00', 'expires_at': '2026-04-08T13:42:48+00:00', 'is_expired': False, 'is_invalidated': False, 'project': {'id': '546796ff-15f1-4dc9-a035-59d1642771b5', 'name': '74bea521-1d27-47fe-bfe9-d5b478c02d18/default', 'role': 'OWNER'}}}
