# %% [markdown]
# # Access management

# %% [markdown]
# ## Access to management function with identity token

# %%
from libs.helpers.utils import get_featuremesh_config

fm_config = get_featuremesh_config()

__YOUR_IDENTITY_TOKEN__ = fm_config['identity_token']

# %%
import featuremesh
from featuremesh import AccessClient

featuremesh.set_default('access.host', fm_config['access.host'])

client_access = AccessClient(identity_token=__YOUR_IDENTITY_TOKEN__)
client_access.list_projects()
# Out:
# [{'project_id': '59e986db-2794-4b12-8b5f-f6f153108b2b',
#   'project_reference': '3565441d-6f0b-4903-afa8-f170a13a6f2d/default',
#   'org_name': '3565441d-6f0b-4903-afa8-f170a13a6f2d',
#   'project_name': 'default',
#   'role': 'OWNER',
#   'granted_at': '2025-11-12T11:13:31.190308'},
#  {'project_id': '886e43fe-0086-4eca-85af-7bf948378058',
#   'project_reference': 'nics_org/nics_project',
#   'org_name': 'nics_org',
#   'project_name': 'nics_project',
#   'role': 'OWNER',
#   'granted_at': '2025-11-12T11:36:42.877894'}]

# %% [markdown]
# ## Access to a project with an identity token

# %%
from featuremesh import generate_access_token

__YOUR_ACCESS_TOKEN__ = generate_access_token(
    identity_token=__YOUR_IDENTITY_TOKEN__, 
    project='default'
)

# %%
from featuremesh import OfflineClient, Backend
import duckdb

featuremesh.set_default('registry.host', fm_config['registry.host'])
client_duckdb = OfflineClient(
    access_token=__YOUR_ACCESS_TOKEN__,
    backend=Backend.DUCKDB,
    sql_executor=lambda sql: duckdb.sql(sql).df()
)
client_duckdb.query('SELECT 1+2').dataframe
# Out:
#    UNNAMED_FEATURE_28FUVH
# 0                       3

# %% [markdown]
# ## Decode any token

# %%
from featuremesh import decode_token

print("Identity token:\n", decode_token(__YOUR_IDENTITY_TOKEN__))
print("\nAccess token:\n", decode_token(__YOUR_ACCESS_TOKEN__))
# Out:
# Identity token:
#  {'success': True, 'token_info': {'token_type': 'USER_TOKEN', 'user_id': '3565441d-6f0b-4903-afa8-f170a13a6f2d', 'email': 'nicolas.pissard@featuremesh.com', 'issued_at': '2025-11-12T11:13:31+00:00', 'expires_at': '2025-11-19T11:13:31+00:00', 'is_expired': False, 'is_invalidated': False}}
# Access token:
#  {'success': True, 'token_info': {'token_type': 'USER_PROJECT_TOKEN', 'user_id': '3565441d-6f0b-4903-afa8-f170a13a6f2d', 'email': 'nicolas.pissard@featuremesh.com', 'issued_at': '2025-11-12T14:38:15+00:00', 'expires_at': '2025-11-13T14:38:15+00:00', 'is_expired': False, 'is_invalidated': False, 'project': {'id': '59e986db-2794-4b12-8b5f-f6f153108b2b', 'name': '3565441d-6f0b-4903-afa8-f170a13a6f2d/default', 'role': 'OWNER'}}}
