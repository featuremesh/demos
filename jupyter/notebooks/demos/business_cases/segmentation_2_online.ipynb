# %% [markdown]
# # Segmentation 2 - Online

# %% [markdown]
# The goal of this notebook is to reuse the features created in offline to call it from production code, so that we can show promocodes on the app.

# %% [markdown]
# ## Setup environment

# %%
from IPython.display import HTML, display

import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
import featuremesh
# %reload_ext featuremesh

from featuremesh import generate_access_token, decode_token

from libs.helpers.utils import get_featuremesh_config

fm_config = get_featuremesh_config()

featuremesh.set_default('managed.host', fm_config['managed.host'])
featuremesh.set_default('access.host', fm_config['access.host'])
# featuremesh.set_default('serving.host', "http://host.docker.internal:10092")

__YOUR_IDENTITY_TOKEN__ = fm_config['identity_token']
__YOUR_ACCESS_TOKEN__ = generate_access_token(identity_token=__YOUR_IDENTITY_TOKEN__, project='default')

# decode_token(__YOUR_ACCESS_TOKEN__)

# %%
from libs.helpers.utils_db import query_duckdb as query_duckdb_direct

def kill_duckdb_pid(pid):
    import os
    import signal
    os.kill(pid, signal.SIGTERM)

def query_duckdb(sql: str) -> pd.DataFrame:
    return query_duckdb_direct(sql, storage_path="/files/local1.db")  # You need to interrupt the kernel of notebooks that run the same connexion

client_duckdb = featuremesh.OfflineClient(
    access_token=__YOUR_ACCESS_TOKEN__, 
    backend=featuremesh.Backend.DUCKDB, 
    sql_executor=query_duckdb
)

client_online = featuremesh.OnlineClient(
    access_token=__YOUR_ACCESS_TOKEN__
)

featuremesh.set_default('client', client_online)  # Allow to use %%featureql magic command without specifying the client

# %%
# kill_duckdb_pid(6548)

# %% [markdown]
# ## Step 1: Use a low latency key-value store (redis)

# %%
from libs.helpers.utils import get_redis_connection_config

import redis
try:
    redis_config = get_redis_connection_config(port=6380)
    r = redis.Redis(**redis_config)
    r.ping()
    print("Connected to Redis successfully")
except redis.exceptions.ConnectionError:
    print("Could not connect to Redis. Please check if Redis is running and the connection details are correct.")
except redis.exceptions.TimeoutError:
    print("Connection to Redis timed out. Please check your network settings and Redis server status.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# Connected to Redis successfully

# %%
r.flushall()
# Out:
# True

# %%
# Write data to Redis
r.set('my_key', 'Hello, Redis!')

# Write data to Redis through a COMMAND
r.execute_command('SET customer_id:1 orders_of_customer_1')

# Read data from Redis
value = r.get('my_key')
print(value.decode('utf-8'))  # Output: Hello, Redis!

value = r.get('customer_id:1')
print(value)
# Out:
# Hello, Redis!
# b'orders_of_customer_1'

# %%
r.flushall()
# Out:
# True

# %% [markdown]
# ## Step 2: Ingest data from data lake to redis (mimicing reverse ETL)
# We could also directly use transactional data through postgres data source

# %%
sql = "SELECT h_custkey, h_datefirstorder, h_datelastorder, h_totalprice FROM tpch.customer_history ORDER BY h_custkey LIMIT 100"
records = query_duckdb(sql).to_dict('records')

can_spend_money_on_redis = False

for record in records:
    
    record['h_datefirstorder'] = record['h_datefirstorder'].strftime('%Y-%m-%d')
    record['h_datelastorder'] = record['h_datelastorder'].strftime('%Y-%m-%d')
    
    key = f"customer:h_datefirstorder:{ record['h_custkey'] }"
    value_txt = str(record['h_datefirstorder'])
    r.set(key, value_txt)
    
    key = f"customer:h_datelastorder:{ record['h_custkey'] }"
    value_txt = str(record['h_datelastorder'])
    r.set(key, value_txt)
    
    key = f"customer:h_totalprice:{ record['h_custkey'] }"
    value_txt = str(record['h_totalprice'])
    r.set(key, value_txt)
    
    if can_spend_money_on_redis:
        key = f"customer:h_listorders:{ record['h_custkey'] }"
        list_orders = []
        for order in record['h_listorders']:
            list_orders.append({
                'o_orderkey': int(order['o_orderkey']), 
                'o_orderdate': str(order['o_orderdate']), 
                'o_totalprice': float(order['o_totalprice']), 
            })
        value_txt = json.dumps(list_orders)
        r.set(key, value_txt)

# %% [markdown]
# ### Check that values are in redis

# %%
num_customers = len(list(r.scan_iter(match="customer:h_datefirstorder:*")))
num_customers
# Out:
# 100

# %%
r.get('customer:h_datefirstorder:2').decode('utf-8')
# Out:
# '1992-12-07'

# %% [markdown]
# ## Step 3: Create a feature source

# %%
# %%featureql
#
# CREATE OR REPLACE FEATURES AS
# SELECT
#     FM.DEMOS_RT.REDIS_CNX1 := SOURCE_REDIS('redis://host.docker.internal:6380' WITH (timeout='500ms')),
# ;
# Out:
#              FEATURE_NAME    STATUS               MESSAGE
# 0  FM.DEMOS_RT.REDIS_CNX1  REPLACED  Feature was replaced

# %%
# %%featureql --client client_online --hook output
#
# SHOW FEATURES (INCLUDE ('PROPERTIES')) WHERE NAME='FM.DEMOS_RT.REDIS_CNX1'
# Out:
# INFO: The output has been stored as a dict in variable 'output'
#                      NAME     DATATYPE      FUNCTION INPUTS  \
# 0  FM.DEMOS_RT.REDIS_CNX1  REDISSOURCE  SOURCE_REDIS     []
#
#                                                                                                                       FORMULA  \
# 0  SOURCE_REDIS( json_object( 'function', 'SOURCE_REDIS' , 'uri', 'redis://host.docker.internal:6380' , 'timeout', '500ms' ))
#
#   RESTRICTIONS STATUS META                        SIGNATURE  POSITION  \
# 0   ["ONLINE"]    DEV   {}  SOURCE_REDIS.custom.REDISSOURCE        50
#
#                     DEPENDENCIES               CREATED_AT CREATED_BY  \
# 0  {"FM.DEMOS_RT.REDIS_CNX1": 1}  2026-03-04T09:58:53.656       None
#
#                 UPDATED_AT                            UPDATED_BY  \
# 0  2026-03-04T09:58:53.660  984b00d0-6753-4a00-8c41-fe678e619e7e
#
#                                                                                                                   PROPERTIES
# 0  {"config_as_json": "{\"function\":\"SOURCE_REDIS\",\"uri\":\"redis://host.docker.internal:6380\",\"timeout\":\"500ms\"}"}

# %% [markdown]
# ## Step 4: Prototype feature based on new source
#
# By using composability, we can re-use business logic from the offline feature (FM.DEMOS.SEND_PROMOCODE) applied to the online case.
#
# We hardcode mock values for the FM.DEMOS_RT.*_TXT features so that we can prototype the "pure" part of the transformnation.

# %%
# %%featureql
#
# SELECT
#     FM.CORE.CUSTOMER_ID := BIND_VALUES(ARRAY[1,2,3,4]),
#
#     -- Here we test on mocked up values
#     FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT := '1992-12-07',
#     FM.DEMOS_RT.CUSTOMER_DATELAST_TXT := '1998-05-22',
#     FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT := '1744996.1',
#
#     FM.DEMOS_RT.CUSTOMER_DATEFIRST := CAST(FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT AS DATE),
#     FM.DEMOS_RT.CUSTOMER_DATELAST := CAST(FM.DEMOS_RT.CUSTOMER_DATELAST_TXT AS DATE),
#     FM.DEMOS_RT.CUSTOMER_TOTALPRICE := CAST(FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT AS DOUBLE),
#
#     FM.DEMOS_RT.SHOW_PROMOCODE := VARIANT(
#         FM.DEMOS.SEND_PROMOCODE
#         REPLACING FEATURES
#             FM.DEMOS.CUSTOMER_DATEFIRST,
#             FM.DEMOS.CUSTOMER_DATELAST,
#             FM.DEMOS.CUSTOMER_TOTALPRICE
#         WITH
#             FM.DEMOS_RT.CUSTOMER_DATEFIRST,
#             FM.DEMOS_RT.CUSTOMER_DATELAST,
#             FM.DEMOS_RT.CUSTOMER_TOTALPRICE
#     )
# ;
# Out:
#    FM__CORE__CUSTOMER_ID FM__DEMOS_RT__CUSTOMER_DATEFIRST_TXT  \
# 0                      1                           1992-12-07
# 1                      2                           1992-12-07
# 2                      3                           1992-12-07
# 3                      4                           1992-12-07
#
#   FM__DEMOS_RT__CUSTOMER_DATELAST_TXT FM__DEMOS_RT__CUSTOMER_TOTALPRICE_TXT  \
# 0                          1998-05-22                             1744996.1
# 1                          1998-05-22                             1744996.1
# 2                          1998-05-22                             1744996.1
# 3                          1998-05-22                             1744996.1
#
#   FM__DEMOS_RT__CUSTOMER_DATEFIRST FM__DEMOS_RT__CUSTOMER_DATELAST  \
# 0                       1992-12-07                      1998-05-22
# 1                       1992-12-07                      1998-05-22
# 2                       1992-12-07                      1998-05-22
# 3                       1992-12-07                      1998-05-22
#
#    FM__DEMOS_RT__CUSTOMER_TOTALPRICE  FM__DEMOS_RT__SHOW_PROMOCODE
# 0                          1744996.1                          True
# 1                          1744996.1                          True
# 2                          1744996.1                          True
# 3                          1744996.1                          True

# %% [markdown]
# ## Step 5: Persist these features
#
# Using the real redis sources instead of text literals
#
# **TODO:** Bug when creating all the features in one go. For now, create one by one.

# %%
# %%featureql
#
# CREATE OR REPLACE FEATURES IN FM.DEMOS_RT AS
# SELECT
#     CUSTOMER_DATEFIRST_TXT := EXTERNAL_REDIS(KEY 'customer:h_datefirstorder:' || UNSAFE_CAST(FM.CORE.CUSTOMER_ID AS VARCHAR) FROM REDIS_CNX1),
#     CUSTOMER_DATELAST_TXT := EXTERNAL_REDIS(KEY 'customer:h_datelastorder:' || UNSAFE_CAST(FM.CORE.CUSTOMER_ID AS VARCHAR) FROM REDIS_CNX1),
#     CUSTOMER_TOTALPRICE_TXT := EXTERNAL_REDIS(KEY 'customer:h_totalprice:' || UNSAFE_CAST(FM.CORE.CUSTOMER_ID AS VARCHAR) FROM REDIS_CNX1),
#
#     CUSTOMER_DATEFIRST := CAST(CUSTOMER_DATEFIRST_TXT AS DATE),
#     CUSTOMER_DATELAST := CAST(CUSTOMER_DATELAST_TXT AS DATE),
#     CUSTOMER_TOTALPRICE := CAST(CUSTOMER_TOTALPRICE_TXT AS DOUBLE)
# Out:
#                           FEATURE_NAME    STATUS               MESSAGE
# 0   FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT  REPLACED  Feature was replaced
# 1    FM.DEMOS_RT.CUSTOMER_DATELAST_TXT  REPLACED  Feature was replaced
# 2  FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT  REPLACED  Feature was replaced
# 3       FM.DEMOS_RT.CUSTOMER_DATEFIRST  REPLACED  Feature was replaced
# 4        FM.DEMOS_RT.CUSTOMER_DATELAST  REPLACED  Feature was replaced
# 5      FM.DEMOS_RT.CUSTOMER_TOTALPRICE  REPLACED  Feature was replaced

# %%
# Check that features were correctly created
output = client_duckdb.query("SHOW FEATURES IN FM.DEMOS_RT")
assert(len(output.dataframe)>=7)

# %%
output
# Out:
# QueryResult(featureql='SHOW FEATURES IN FM.DEMOS_RT', sql='\n            SELECT\n                NAME,\n                DATATYPE,\n                FUNCTION,\n                INPUTS,\n                FORMULA,\n                RESTRICTIONS,\n                STATUS,\n                META,\n                SIGNATURE,\n                POSITION,\n                DEPENDENCIES,\n                CREATED_AT,\n                CREATED_BY,\n                UPDATED_AT,\n                UPDATED_BY\n                \n            FROM\n            (\n                VALUES\n                (\n                    CAST(\'FM.DEMOS_RT.CUSTOMER_TOTALPRICE\' AS VARCHAR),\n                    CAST(\'DOUBLE\' AS VARCHAR),\n                    CAST(\'CAST\' AS VARCHAR),\n                    CAST(\'[]\' AS JSON),\n                    CAST(\'CAST(FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT AS DOUBLE)\' AS VARCHAR),\n                    CAST(\'["ONLINE"]\' AS JSON),\n                    CAST(\'DEV\' AS VARCHAR),\n                    CAST(\'{}\' AS JSON),\n                    CAST(\'CAST.custom.DOUBLE\' AS VARCHAR),\n                    CAST(\'50\' AS BIGINT),\n                    CAST(\'{"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_2TQVX3": 3, "UNNAMED_FEATURE_9K2FFQ": 2, "FM.DEMOS_RT.CUSTOMER_TOTALPRICE": 5, "FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT": 4}\' AS JSON),\n                    CAST(\'2026-03-04 09:58:54.058000\' AS TIMESTAMP(3)),\n                    CAST(NULL AS VARCHAR),\n                    CAST(\'2026-03-04 09:58:54.060000\' AS TIMESTAMP(3)),\n                    CAST(\'984b00d0-6753-4a00-8c41-fe678e619e7e\' AS VARCHAR)\n                    \n                ),\n                (\n                    CAST(\'FM.DEMOS_RT.CUSTOMER_DATELAST\' AS VARCHAR),\n                    CAST(\'DATE\' AS VARCHAR),\n                    CAST(\'CAST\' AS VARCHAR),\n                    CAST(\'[]\' AS JSON),\n                    CAST(\'CAST(FM.DEMOS_RT.CUSTOMER_DATELAST_TXT AS DATE)\' AS VARCHAR),\n                    CAST(\'["ONLINE"]\' AS JSON),\n                    CAST(\'DEV\' AS VARCHAR),\n                    CAST(\'{}\' AS JSON),\n                    CAST(\'CAST.custom.DATE\' AS VARCHAR),\n                    CAST(\'50\' AS BIGINT),\n                    CAST(\'{"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_2UAP9T": 3, "UNNAMED_FEATURE_GA2X89": 2, "FM.DEMOS_RT.CUSTOMER_DATELAST": 5, "FM.DEMOS_RT.CUSTOMER_DATELAST_TXT": 4}\' AS JSON),\n                    CAST(\'2026-03-04 09:58:54.055000\' AS TIMESTAMP(3)),\n                    CAST(NULL AS VARCHAR),\n                    CAST(\'2026-03-04 09:58:54.057000\' AS TIMESTAMP(3)),\n                    CAST(\'984b00d0-6753-4a00-8c41-fe678e619e7e\' AS VARCHAR)\n                    \n                ),\n                (\n                    CAST(\'FM.DEMOS_RT.CUSTOMER_DATEFIRST\' AS VARCHAR),\n                    CAST(\'DATE\' AS VARCHAR),\n                    CAST(\'CAST\' AS VARCHAR),\n                    CAST(\'[]\' AS JSON),\n                    CAST(\'CAST(FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT AS DATE)\' AS VARCHAR),\n                    CAST(\'["ONLINE"]\' AS JSON),\n                    CAST(\'DEV\' AS VARCHAR),\n                    CAST(\'{}\' AS JSON),\n                    CAST(\'CAST.custom.DATE\' AS VARCHAR),\n                    CAST(\'50\' AS BIGINT),\n                    CAST(\'{"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_CNQ8DX": 3, "UNNAMED_FEATURE_MJ3DX9": 2, "FM.DEMOS_RT.CUSTOMER_DATEFIRST": 5, "FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT": 4}\' AS JSON),\n                    CAST(\'2026-03-04 09:58:54.052000\' AS TIMESTAMP(3)),\n                    CAST(NULL AS VARCHAR),\n                    CAST(\'2026-03-04 09:58:54.054000\' AS TIMESTAMP(3)),\n                    CAST(\'984b00d0-6753-4a00-8c41-fe678e619e7e\' AS VARCHAR)\n                    \n                ),\n                (\n                    CAST(\'FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT\' AS VARCHAR),\n                    CAST(\'VARCHAR\' AS VARCHAR),\n                  ...
# 0           FM.DEMOS_RT.CUSTOMER_TOTALPRICE              DOUBLE
# 1             FM.DEMOS_RT.CUSTOMER_DATELAST                DATE
# 2            FM.DEMOS_RT.CUSTOMER_DATEFIRST                DATE
# 3       FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT             VARCHAR
# 4         FM.DEMOS_RT.CUSTOMER_DATELAST_TXT             VARCHAR
# 5        FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT             VARCHAR
# 6                    FM.DEMOS_RT.REDIS_CNX1         REDISSOURCE
# 7           FM.DEMOS_RT.SHOW_PROMOCODE_V_PS  PREPARED_STATEMENT
# 8              FM.DEMOS_RT.SHOW_PROMOCODE_V             BOOLEAN
# 9                FM.DEMOS_RT.SHOW_PROMOCODE             BOOLEAN
# 10             FM.DEMOS_RT.HAS_RECENT_ORDER             BOOLEAN
# 11  FM.DEMOS_RT.LIFETIME_REVENUE_GT_1000000             BOOLEAN
# 12              FM.DEMOS_RT.IS_OLD_CUSTOMER             BOOLEAN
#
#               FUNCTION INPUTS  \
# 0                 CAST     []
# 1                 CAST     []
# 2                 CAST     []
# 3       EXTERNAL_REDIS     []
# 4       EXTERNAL_REDIS     []
# 5       EXTERNAL_REDIS     []
# 6         SOURCE_REDIS     []
# 7   PREPARED_STATEMENT     []
# 8              VARIANT     []
# 9                  AND     []
# 10           LESS_THAN     []
# 11        GREATER_THAN     []
# 12        GREATER_THAN     []
#
#                                                                                                                                                                                                                                                                                                               FORMULA  \
# 0                                                                                                                                                                                                                                                                 CAST(FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT AS DOUBLE)
# 1                                                                                                                                                                                                                                                                     CAST(FM.DEMOS_RT.CUSTOMER_DATELAST_TXT AS DATE)
# 2                                                                                                                                                                                                                                                                    CAST(FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT AS DATE)
# 3                                                                                  \n            \n                EXTERNAL_REDIS('FM.DEMOS_RT.REDIS_CNX1', \n            \n            CONCAT('customer:h_totalprice:',UNSAFE_CAST(FM.CORE.CUSTOMER_ID AS VARCHAR))\n            \n        )\n            \n
# 4                                                                               \n            \n                EXTERNAL_REDIS('FM.DEMOS_RT.REDIS_CNX1', \n            \n            CONCAT('customer:h_datelastorder:',UNSAFE_CAST(FM.CORE.CUSTOMER_ID AS VARCHAR))\n            \n        )\n            \n
# 5                                                                              \n            \n                EXTERNAL_REDIS('FM.DEMOS_RT.REDIS_CNX1', \n            \n            CONCAT('customer:h_datefirstorder:',UNSAFE_CAST(FM.CORE.CUSTOMER_ID AS VARCHAR))\n            \n        )\n            \n
# 6   SOURCE_REDIS(\n        json_object(\n            'function', 'SOURCE_REDIS'\n            \n            , 'uri', 'redis://host.docker.internal:6380'\n            \n            \n            \n            \n            \n            , 'timeout', '500ms'\n            \n            \n            \n        ))
# 7                                                                                                                                                                                                                                                 ERROR_COMPUTING_FORMULA : 'str object' has no attribute 'get_value'
# 8                                                                                                                                                                                                                                                 ERROR_COMPUTING_FORMULA : 'str object' has no attribute 'get_value'
# 9                                                                                                                                                                                                      FM.DEMOS_RT.IS_OLD_CUSTOMER AND FM.DEMOS_RT.LIFETIME_REVENUE_GT_1000000) AND (NOT FM.DEMOS_RT.HAS_RECENT_ORDER
# 10                                                                                                                                                                                                                                                ERROR_COMPUTING_FORMULA : 'str object' has no attribute 'get_value'
# 11                                                                                                                                            \n            \n                (CAST(CAST(FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT AS DOUBLE) AS DECIMAL(18,5)) > CAST(1000000.0 AS DECIMAL(18,5)))\n            \n
# 12                                                                                                                                                                                                                                                ERROR_COMPUTING_FORMULA : 'str object' has no attribute 'get_value'
#
#    RESTRICTIONS STATUS META                                     SIGNATURE  \
# 0    ["ONLINE"]    DEV   {}                            CAST.custom.DOUBLE
# 1    ["ONLINE"]    DEV   {}                              CAST.custom.DATE
# 2    ["ONLINE"]    DEV   {}                              CAST.custom.DATE
# 3    ["ONLINE"]    DEV   {}                 EXTERNAL_REDIS.custom.VARCHAR
# 4    ["ONLINE"]    DEV   {}                 EXTERNAL_REDIS.custom.VARCHAR
# 5    ["ONLINE"]    DEV   {}                 EXTERNAL_REDIS.custom.VARCHAR
# 6    ["ONLINE"]    DEV   {}               SOURCE_REDIS.custom.REDISSOURCE
# 7            []    DEV   {}  PREPARED_STATEMENT.custom.PREPARED_STATEMENT
# 8            []    DEV   {}                        VARIANT.custom.BOOLEAN
# 9            []    DEV   {}                   AND.BOOLEAN.BOOLEAN.BOOLEAN
# 10           []    DEV   {}                      LESS_THAN.custom.BOOLEAN
# 11           []    DEV   {}                   GREATER_THAN.custom.BOOLEAN
# 12           []    DEV   {}                   GREATER_THAN.custom.BOOLEAN
#
#     POSITION  \
# 0         50
# 1         50
# 2         50
# 3         50
# 4         50
# 5         50
# 6         50
# 7         50
# 8         50
# 9         50
# 10        50
# 11        50
# 12        50
#
#                                                                                                                                                                                                                                                                                                                           DEPENDENCIES  \
# 0                                                                                                                                                                 {"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_2TQVX3": 3, "UNNAMED_FEATURE_9K2FFQ": 2, "FM.DEMOS_RT.CUSTOMER_TOTALPRICE": 5, "FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT": 4}
# 1                                                                                                                                                                     {"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_2UAP9T": 3, "UNNAMED_FEATURE_GA2X89": 2, "FM.DEMOS_RT.CUSTOMER_DATELAST": 5, "FM.DEMOS_RT.CUSTOMER_DATELAST_TXT": 4}
# 2                                                                                                                                                                   {"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_CNQ8DX": 3, "UNNAMED_FEATURE_MJ3DX9": 2, "FM.DEMOS_RT.CUSTOMER_DATEFIRST": 5, "FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT": 4}
# 3                                                                                                                                                                                                       {"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_2TQVX3": 3, "UNNAMED_FEATURE_9K2FFQ": 2, "FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT": 4}
# 4                                                                                                                                                                                                         {"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_2UAP9T": 3, "UNNAMED_FEATURE_GA2X89": 2, "FM.DEMOS_RT.CUSTOMER_DATELAST_TXT": 4}
# 5                                                                                                                                                                                                        {"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_CNQ8DX": 3, "UNNAMED_FEATURE_MJ3DX9": 2, "FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT": 4}
# 6                                                                                                                                                                                                                                                                                                        {"FM.DEMOS_RT.REDIS_CNX1": 1}
# 7                                                                                                                                                                                                                                                                                               {"FM.DEMOS_RT.SHOW_PROMOCODE_V_PS": 1}
# 8                                                                                                                                                                                                                                                                                                  {"FM.DEMOS_RT.SHOW_PROMOCODE_V": 1}
# 9   {"UNNAMED_FEATURE_25ZZ28": 4, "UNNAMED_FEATURE_3E3KN2": 2, "UNNAMED_FEATURE_C7UA9Y": 1, "UNNAMED_FEATURE_FH64BZ": 1, "UNNAMED_FEATURE_VN4BB2": 2, "UNNAMED_FEATURE_Z6UW3A": 4, "FM.DEMOS_RT.SHOW_PROMOCODE": 5, "FM.DEMOS_RT.IS_OLD_CUSTOMER": 3, "FM.DEMOS_RT.HAS_RECENT_ORDER": 3, "FM.DEMOS_RT.LIFETIME_REVENUE_GT_1000000": 1}
# 10                                                                                                                                                                                                                                       {"UNNAMED_FEATURE_3E3KN2": 2, "UNNAMED_FEATURE_C7UA9Y": 1, "FM.DEMOS_RT.HAS_RECENT_ORDER": 3}
# 11                                                                                                                                                                                                                                                                                      {"FM.DEMOS_RT.LIFETIME_REVENUE_GT_1000000": 1}
# 12                                                                                                                                                                                                                                        {"UNNAMED_FEATURE_FH64BZ": 1, "UNNAMED_FEATURE_VN4BB2": 2, "FM.DEMOS_RT.IS_OLD_CUSTOMER": 3}
#
#                 CREATED_AT                            CREATED_BY  \
# 0  2026-03-04 09:58:54.058                                   NaN
# 1  2026-03-04 09:58:54.055                                   NaN
# 2  2026-03-04 09:58:54.052                                   NaN
# 3  2026-03-04 09:58:54.047                                   NaN
# 4  2026-03-04 09:58:54.043                                   NaN
# 5  2026-03-04 09:58:54.038                                   NaN
# 6  2026-03-04 09:58:53.656                                   NaN
# 7  2026-03-03 18:38:28.386  984b00d0-6753-4a00-8c41-fe678e619e7e
# 8  2026-03-03 18:38:04.153  984b00d0-6753-4a00-8c41-fe678e619e7e
# 9  2026-03-03 18:38:01.606  984b00d0-6753-4a00-8c41-fe678e619e7e
# 10 2026-03-03 18:38:01.604  984b00d0-6753-4a00-8c41-fe678e619e7e
# 11 2026-03-03 18:38:01.601  984b00d0-6753-4a00-8c41-fe678e619e7e
# 12 2026-03-03 18:38:01.596  984b00d0-6753-4a00-8c41-fe678e619e7e
#
#                 UPDATED_AT                            UPDATED_BY
# 0  2026-03-04 09:58:54.060  984b00d0-6753-4a00-8c41-fe678e619e7e
# 1  2026-03-04 09:58:54.057  984b00d0-6753-4a00-8c41-fe678e619e7e
# 2  2026-03-04 09:58:54.054  984b00d0-6753-4a00-8c41-fe678e619e7e
# 3  2026-03-04 09:58:54.050  984b00d0-6753-4a00-8c41-fe678e619e7e
# 4  2026-03-04 09:58:54.045  984b00d0-6753-4a00-8c41-fe678e619e7e
# 5  2026-03-04 09:58:54.041  984b00d0-6753-4a00-8c41-fe678e619e7e
# 6  2026-03-04 09:58:53.660  984b00d0-6753-4a00-8c41-fe678e619e7e
# 7  2026-03-03 18:38:28.386  984b00d0-6753-4a00-8c41-fe678e619e7e
# 8  2026-03-03 18:38:04.153  984b00d0-6753-4a00-8c41-fe678e619e7e
# 9  2026-03-03 18:38:01.606  984b00d0-6753-4a00-8c41-fe678e619e7e
# 10 2026-03-03 18:38:01.604  984b00d0-6753-4a00-8c41-fe678e619e7e
# 11 2026-03-03 18:38:01.601  984b00d0-6753-4a00-8c41-fe678e619e7e
# 12 2026-03-03 18:38:01.596  984b00d0-6753-4a00-8c41-fe678e619e7e  , slt='query NAME:V,DATATYPE:V,FUNCTION:V,INPUTS:J,FORMULA:V,RESTRICTIONS:J,STATUS:V,META:J,SIGNATURE:V,POSITION:I,DEPENDENCIES:J,CREATED_AT:?TIMESTAMP(3),CREATED_BY:V,UPDATED_AT:?TIMESTAMP(3),UPDATED_BY:V\nSHOW FEATURES IN FM.DEMOS_RT\n----\nFM.DEMOS_RT.CUSTOMER_TOTALPRICE\tDOUBLE\tCAST\t[]\tCAST(FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT AS DOUBLE)\t["ONLINE"]\tDEV\t{}\tCAST.custom.DOUBLE\t50\t{"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_2TQVX3": 3, "UNNAMED_FEATURE_9K2FFQ": 2, "FM.DEMOS_RT.CUSTOMER_TOTALPRICE": 5, "FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT": 4}\t2026-03-04T09:58:54\tNaN\t2026-03-04T09:58:54\t984b00d0-6753-4a00-8c41-fe678e619e7e\nFM.DEMOS_RT.CUSTOMER_DATELAST\tDATE\tCAST\t[]\tCAST(FM.DEMOS_RT.CUSTOMER_DATELAST_TXT AS DATE)\t["ONLINE"]\tDEV\t{}\tCAST.custom.DATE\t50\t{"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_2UAP9T": 3, "UNNAMED_FEATURE_GA2X89": 2, "FM.DEMOS_RT.CUSTOMER_DATELAST": 5, "FM.DEMOS_RT.CUSTOMER_DATELAST_TXT": 4}\t2026-03-04T09:58:54\tNaN\t2026-03-04T09:58:54\t984b00d0-6753-4a00-8c41-fe678e619e7e\nFM.DEMOS_RT.CUSTOMER_DATEFIRST\tDATE\tCAST\t[]\tCAST(FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT AS DATE)\t["ONLINE"]\tDEV\t{}\tCAST.custom.DATE\t50\t{"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_CNQ8DX": 3, "UNNAMED_FEATURE_MJ3DX9": 2, "FM.DEMOS_RT.CUSTOMER_DATEFIRST": 5, "FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT": 4}\t2026-03-04T09:58:54\tNaN\t2026-03-04T09:58:54\t984b00d0-6753-4a00-8c41-fe678e619e7e\nFM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT\tVARCHAR\tEXTERNAL_REDIS\t[]\tEXTERNAL_REDIS(FM.DEMOS_RT.REDIS_CNX1, CONCAT(customer:h_totalprice:,UNSAFE_CAST(FM.CORE.CUSTOMER_ID AS VARCHAR)) )\t["ONLINE"]\tDEV\t{}\tEXTERNAL_REDIS.custom.VARCHAR\t50\t{"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_2TQVX3": 3, "UNNAMED_FEATURE_9K2FFQ": 2, "FM.DEMOS_RT.CUSTOMER_TOTALPRICE_TXT": 4}\t2026-03-04T09:58:54\tNaN\t2026-03-04T09:58:54\t984b00d0-6753-4a00-8c41-fe678e619e7e\nFM.DEMOS_RT.CUSTOMER_DATELAST_TXT\tVARCHAR\tEXTERNAL_REDIS\t[]\tEXTERNAL_REDIS(FM.DEMOS_RT.REDIS_CNX1, CONCAT(customer:h_datelastorder:,UNSAFE_CAST(FM.CORE.CUSTOMER_ID AS VARCHAR)) )\t["ONLINE"]\tDEV\t{}\tEXTERNAL_REDIS.custom.VARCHAR\t50\t{"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_2UAP9T": 3, "UNNAMED_FEATURE_GA2X89": 2, "FM.DEMOS_RT.CUSTOMER_DATELAST_TXT": 4}\t2026-03-04T09:58:54\tNaN\t2026-03-04T09:58:54\t984b00d0-6753-4a00-8c41-fe678e619e7e\nFM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT\tVARCHAR\tEXTERNAL_REDIS\t[]\tEXTERNAL_REDIS(FM.DEMOS_RT.REDIS_CNX1, CONCAT(customer:h_datefirstorder:,UNSAFE_CAST(FM.CORE.CUSTOMER_ID AS VARCHAR)) )\t["ONLINE"]\tDEV\t{}\tEXTERNAL_REDIS.custom.VARCHAR\t50\t{"FM.CORE.CUSTOMER_ID": 1, "UNNAMED_FEATURE_CNQ8DX": 3, "UNNAMED_FEATURE_MJ3DX9": 2, "FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT": 4}\t2026-03-04T09:58:54\tNaN\t2026-03-04T09:58:54\t984b00d0-6753-4a00-8c41-fe678e619e7e\nFM.DEMOS_RT.REDIS_CNX1\tREDISSOURCE\tSOURCE_REDIS\t[]\tSOURCE_REDIS( json_object( function, SOURCE_REDIS , uri, redis://host.docker.internal:6380 , timeout, 500ms ))\t["ONLINE"]\tDEV\t{}\tSOURCE_REDIS.custom.REDISSOURCE\t50\t{"FM.DEMOS_RT.REDIS_CNX1": 1}\t2026-03-04T09:58:53\tNaN\t2026-03-04T09:58:53\t984b00d0-6753-4a00-8c41-fe678e619e7e\nFM.DEMOS_RT.SHOW_PROMOCODE_V_PS\tPREPARED_STATEMENT\tPREPARED_STATEMENT\t[]\tERROR_COMPUTING_FORMULA : str object has no attribute get_value\t[]\tDEV\t{}\tPREPARED_STATEMENT.custom.PREPARED_STATEMENT\t50\t{"FM.DEMOS_RT.SHOW_PROMOCODE_V_PS": 1}\t2026-03-03T18:38:28\t984b00d0-6753-4a00-8c41-fe678e619e7e\t2026-03-03T18:38:28\t984b00d0-6753-4a00-8c41-fe678e619e7e\nFM.DEMOS_RT.SHOW_PROMOCODE_V\tBOOLEAN\tVARIANT\t[]\tERROR_COMPUTING_FORMULA : str object has no attribute get_value\t[]\tDEV\t{}\tVARIANT.custom.BOOLEAN\t50\t{"FM.DEMOS_RT.SHOW_PROMOCODE_V": 1}\t2026-03-03T18:38:04\t984b00d0-6753-4a00-8c41-fe678e619e7e\t2026-03-03T18:38:04\t984b00d0-6753-4a00-8c41-fe678e619e7e\nFM.DEMOS_RT.SHOW_PROMOCODE\tBOOLEAN\tAND\t[]\tFM.DEMOS_RT.IS_OLD_CUSTOMER AND FM.DEMOS_RT.LIFETIME_REVENUE_GT_1000000) AND (NOT FM.DEMOS_RT.H ...

# %% [markdown]
# ### Create the transformation features reusing the definitions
#
# **TODO:** Bug when creating all the features in one go. For now, create one by one.

# %%
# %%featureql
#
# CREATE OR REPLACE FEATURES IN FM.DEMOS_RT AS
# SELECT
#     IS_OLD_CUSTOMER             := DATE_DIFF(CAST(CUSTOMER_DATEFIRST AS TIMESTAMP), TIMESTAMP '1998-08-02', 'DAY') > 180,
#     LIFETIME_REVENUE_GT_1000000 := CUSTOMER_TOTALPRICE >.5 1000000e0,
#     HAS_RECENT_ORDER            := DATE_DIFF(CAST(CUSTOMER_DATELAST AS TIMESTAMP), TIMESTAMP '1998-08-02', 'DAY') < 60,
#     SHOW_PROMOCODE              := IS_OLD_CUSTOMER AND LIFETIME_REVENUE_GT_1000000 AND NOT HAS_RECENT_ORDER
# Out:
#                               FEATURE_NAME    STATUS               MESSAGE
# 0              FM.DEMOS_RT.IS_OLD_CUSTOMER  REPLACED  Feature was replaced
# 1  FM.DEMOS_RT.LIFETIME_REVENUE_GT_1000000  REPLACED  Feature was replaced
# 2             FM.DEMOS_RT.HAS_RECENT_ORDER  REPLACED  Feature was replaced
# 3               FM.DEMOS_RT.SHOW_PROMOCODE  REPLACED  Feature was replaced

# %% [markdown]
# ### Or better, use a VARIANT to reuse the definitions from analytics

# %%
# %%featureql
#
# CREATE OR REPLACE FEATURES AS
# SELECT
#     FM.DEMOS_RT.SHOW_PROMOCODE_V := VARIANT(
#         FM.DEMOS.SEND_PROMOCODE
#         REPLACING FEATURES
#             FM.DEMOS.CUSTOMER_DATEFIRST,
#             FM.DEMOS.CUSTOMER_DATELAST,
#             FM.DEMOS.CUSTOMER_TOTALPRICE
#         WITH
#             FM.DEMOS_RT.CUSTOMER_DATEFIRST,
#             FM.DEMOS_RT.CUSTOMER_DATELAST,
#             FM.DEMOS_RT.CUSTOMER_TOTALPRICE
#     )
# Out:
#                    FEATURE_NAME    STATUS               MESSAGE
# 0  FM.DEMOS_RT.SHOW_PROMOCODE_V  REPLACED  Feature was replaced

# %% [markdown]
# ### Check that we have all features registered

# %%
# Check that features were correctly created
output = client_duckdb.query("SHOW FEATURES IN FM.DEMOS_RT")
assert(len(output.dataframe)>=12)

# %% [markdown]
# ### Check we can evaluate using magic commands

# %%
# %%featureql
#
# SELECT
#     FM.CORE.CUSTOMER_ID := BIND_VALUES(ARRAY[1,2,3,4]),
#     FM.DEMOS_RT.CUSTOMER_DATEFIRST_TXT,
#     FM.DEMOS_RT.SHOW_PROMOCODE_V
# Out:
#    FM__CORE__CUSTOMER_ID FM__DEMOS_RT__CUSTOMER_DATEFIRST_TXT  \
# 0                      1                           1992-04-19
# 1                      2                           1992-12-07
# 2                      3                                  NaN
# 3                      4                           1992-06-09
#
#   FM__DEMOS_RT__SHOW_PROMOCODE_V
# 0                           True
# 1                           True
# 2                           None
# 3                          False

# %% [markdown]
# ## Step 5: Call FeatureMesh APIs from "production code"
#
# We do not need to develop a dedicated endpoint to serve these data, reducing system complexity.
#
# It's what we call Feature as a Service (FaaS)

# %% [markdown]
# ### Step 5a: Direct HTTP Call to FeatureMesh backend service

# %%
import requests

def call_api_show_promocode(customer_id: int) -> str:
    params_post = {
        "query": f"""
            SELECT 
                FM.CORE.CUSTOMER_ID := BIND_VALUE({customer_id}),
                FM.DEMOS_RT.CUSTOMER_DATELAST_TXT,
                FM.DEMOS_RT.SHOW_PROMOCODE_V
        """, 
    }
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {__YOUR_ACCESS_TOKEN__}",
    }
    response = requests.post(f"{get_featuremesh_config()['serving.host']}/v1/featureql", json=params_post, headers=headers, timeout=30, verify=False)

    if response.status_code == 200:
        return response.json()
    else:
        print(f'A non HTTP 200 response occured: {response=}: {response.text}')

# %%
# See send promocode for customer 1,2,3,4
for customer_id in range(1,5):
    output = call_api_show_promocode(customer_id)
    # print(output)
    print(output['data']['rows'])
# Out:
# [{'fm__core__customer_id': 1, 'fm__demos_rt__customer_datelast_txt': '1997-03-04', 'fm__demos_rt__show_promocode_v': True}]
# [{'fm__core__customer_id': 2, 'fm__demos_rt__customer_datelast_txt': '1998-05-22', 'fm__demos_rt__show_promocode_v': True}]
# [{'fm__core__customer_id': 3, 'fm__demos_rt__customer_datelast_txt': None, 'fm__demos_rt__show_promocode_v': None}]
# [{'fm__core__customer_id': 4, 'fm__demos_rt__customer_datelast_txt': '1998-06-15', 'fm__demos_rt__show_promocode_v': False}]

# %%
# Simulate a new order for customer 2
r.set('customer:h_datelastorder:2', '1998-08-01')
# Out:
# True

# %%
# Because of the recency of customer 2 has changed, the value for send_promocode passed to False
for customer_id in range(1,5):
    output = call_api_show_promocode(customer_id)
    #print(output)
    print(output['data']['rows'])
# Out:
# [{'fm__core__customer_id': 1, 'fm__demos_rt__customer_datelast_txt': '1997-03-04', 'fm__demos_rt__show_promocode_v': True}]
# [{'fm__core__customer_id': 2, 'fm__demos_rt__customer_datelast_txt': '1998-08-01', 'fm__demos_rt__show_promocode_v': False}]
# [{'fm__core__customer_id': 3, 'fm__demos_rt__customer_datelast_txt': None, 'fm__demos_rt__show_promocode_v': None}]
# [{'fm__core__customer_id': 4, 'fm__demos_rt__customer_datelast_txt': '1998-06-15', 'fm__demos_rt__show_promocode_v': False}]

# %% [markdown]
# ### Step 5b: Call FeatureMesh APIs using the python client
#
# If you are calling the online service from python, you can also use the python client directly

# %%
for customer_id in range(1,5):
    query = f"""
        SELECT 
            FM.CORE.CUSTOMER_ID := BIND_VALUE({customer_id}),
            FM.DEMOS_RT.CUSTOMER_DATELAST_TXT,
            FM.DEMOS_RT.SHOW_PROMOCODE_V
    """
    dct = client_online.query(query)
    print(dct.dataframe.to_dict(orient='records'))
# Out:
# [{'FM__CORE__CUSTOMER_ID': 1, 'FM__DEMOS_RT__CUSTOMER_DATELAST_TXT': '1997-03-04', 'FM__DEMOS_RT__SHOW_PROMOCODE_V': True}]
# [{'FM__CORE__CUSTOMER_ID': 2, 'FM__DEMOS_RT__CUSTOMER_DATELAST_TXT': '1998-08-01', 'FM__DEMOS_RT__SHOW_PROMOCODE_V': False}]
# [{'FM__CORE__CUSTOMER_ID': 3, 'FM__DEMOS_RT__CUSTOMER_DATELAST_TXT': None, 'FM__DEMOS_RT__SHOW_PROMOCODE_V': None}]
# [{'FM__CORE__CUSTOMER_ID': 4, 'FM__DEMOS_RT__CUSTOMER_DATELAST_TXT': '1998-06-15', 'FM__DEMOS_RT__SHOW_PROMOCODE_V': False}]

# %% [markdown]
# ## Step 6: Using prepared statements
# The problem of free-form queries is that it is slow and innefficient. In prod, you need to use a prepared statement.
#
# - Step 1: Register a stored procedure feature based on "FM.DEMOS_RT.SHOW_PROMOCODE" with input CUSTOMER_ID
# - Step 2: Call it using the serving endpoint

# %%
# %%featureql
#
# CREATE OR REPLACE FEATURE FM.DEMOS_RT.SHOW_PROMOCODE_V_PS AS
# PREPARED_STATEMENT(
#     FM.DEMOS_RT.SHOW_PROMOCODE_V
#     USING INPUTS FM.CORE.CUSTOMER_ID
# );
# Out:
#                       FEATURE_NAME    STATUS               MESSAGE
# 0  FM.DEMOS_RT.SHOW_PROMOCODE_V_PS  REPLACED  Feature was replaced

# %%
def call_prepared_statement_1arg(feature_name: str, customer_id: int) -> str:
    params_post = {
      "statement": {
        "id": feature_name,
        "inputs": {
            "input_table_1": [[customer_id]],
        }
      }
    }
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {__YOUR_ACCESS_TOKEN__}",
    }
    response = requests.post(f"{get_featuremesh_config()['serving.host']}/v1/featureql", json=params_post, headers=headers, timeout=30, verify=False)

    if response.status_code == 200:
        return response.json()
    else:
        print(f'A non HTTP 200 response occured: {response=}: {response.text}')

# %%
call_prepared_statement_1arg("FM.DEMOS_RT.SHOW_PROMOCODE_V_PS", 2)
# Out:
# {'data': {'schema': {'fields': [{'name': 'fm__core__customer_id',
#      'data_type': 'Int64',
#      'nullable': False,
#      'dict_id': 0,
#      'dict_is_ordered': False,
#      'metadata': {}},
#     {'name': 'fm__demos_rt__show_promocode_v_ps',
#      'data_type': 'Boolean',
#      'nullable': True,
#      'dict_id': 0,
#      'dict_is_ordered': False,
#      'metadata': {}}],
#    'metadata': {}},
#   'rows': [{'fm__core__customer_id': 2,
#     'fm__demos_rt__show_promocode_v_ps': False}]}}

# %% [markdown]
# ### Calling for 100 customers
#
# About 10ms per call.

# %%
# %%time

responses = []
for customer_id in range(1,100):
    responses.append(call_prepared_statement_1arg("FM.DEMOS_RT.SHOW_PROMOCODE_V_PS", customer_id))

print(responses[1].get('data', {}).get('rows', []))
# Out:
# [{'fm__core__customer_id': 2, 'fm__demos_rt__show_promocode_v_ps': False}]
# CPU times: user 78.8 ms, sys: 15.6 ms, total: 94.4 ms
# Wall time: 988 ms
